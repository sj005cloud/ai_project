# %%
import os
print(os.listdir('.'))
# Out:
# ['availability_prediction.ipynb', 'data', 'data_analysis.ipynb', 'importinglibs.ipynb', 'knn_recommendation.ipynb', 'requirements.txt', 'spa.ipynb']

# %%
pip install import-ipynb
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\saraj\smart_parking_assistance\venv\Scripts\python.exe -m pip install --upgrade pip

# %%
import sys
sys.path.append('')  # Adds the current directory to the Python path

from knn_recommendation import recommend_nearest_spots
from data_analysis import analyze_parking_patterns
from availability_prediction import predict_availability

# KNN Recommender
print("Recommended Spots:")
print(recommend_nearest_spots([28.6140, 77.2100]))

# Data Analysis Plot
analyze_parking_patterns()

# Predict Availability
predict_availability()
# Out:
# Recommended Spots:
#   SpotID  Latitude  Longitude       Area
# 1     B2   28.6145    77.2101    Library
# 0     A1   28.6139    77.2090  Main Gate
# 2     C3   28.6150    77.2120    Canteen
# Decision Tree Accuracy: 0.0
# Random Forest Accuracy: 0.0

# %%
# Importing required modules
import sys
import os

# Adding current directory to sys.path
sys.path.append(os.getcwd())

# Importing functions from your other notebooks
from knn_recommendation import recommend_nearest_spots
from data_analysis import analyze_parking_patterns
from availability_prediction import predict_availability

# Simulated user input
user_location = [28.6139, 77.2090]  # Example: Connaught Place, Delhi
desired_time = '2025-04-16 15:30'   # User wants a spot at this time

# Step 1: Recommend nearest spots
print("\n🔍 Searching for nearest available parking spots...")
recommended_spots = recommend_nearest_spots(user_location)
print("Recommended Parking Spots:\n", recommended_spots)

# Step 2: Predict availability for the chosen time
print(f"\n🧠 Predicting availability for {desired_time}...")
predict_availability(desired_time)

# Step 3: Show occupancy patterns for decision making
print("\n📊 Analyzing parking occupancy trends...")
analyze_parking_patterns()
# Out:
# 🔍 Searching for nearest available parking spots...
# Recommended Parking Spots:
#    SpotID  Latitude  Longitude       Area
# 0     A1   28.6139    77.2090  Main Gate
# 1     B2   28.6145    77.2101    Library
# 2     C3   28.6150    77.2120    Canteen
#
# 🧠 Predicting availability for 2025-04-16 15:30...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 24
#      22 # Step 2: Predict availability for the chosen time
#      23 print(f"\n🧠 Predicting availability for {desired_time}...")
# ---> 24 predict_availability(desired_time)
#      26 # Step 3: Show occupancy patterns for decision making
#      27 print("\n📊 Analyzing parking occupancy trends...")
#
# File c:\Users\saraj\OneDrive\Desktop\AI_PROJECT\availability_prediction.py:7, in predict_availability(data_file)
#       6 def predict_availability(data_file='data/historicaloccupency.csv'):
# ...
